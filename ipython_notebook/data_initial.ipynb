# %% [markdown]
# ## Manipulating data to get drive by drive data.

# %%
import os
import csv
import pandas as pd
import numpy as np
import math

# %%
os.system('curl -L -o 2002_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMNGQzY2YyNmUtMTlhYy00YmQyLTg3ZTUtMGI2NDhjNGU4Zjg5&export=download"') 
os.system('curl -L -o 2003_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMODljMmIxNzItNzJjNy00ODJiLWJiNDItMDBlZGMwMjkwOTlk&export=download"')
os.system('curl -L -o 2004_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMMGUyNjVkMWEtOWE2YS00YzI3LWJjYjEtZWU2MTIyNmJhOTk0&export=download"')
os.system('curl -L -o 2005_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMYmIyMTdjNWItMjhiNS00NjJkLWIyYWEtZmI1ZGM4NmFmZGQy&export=download"')
os.system('curl -L -o 2006_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMN2YxNGM0MzUtYTc2Mi00YjVjLWI3N2EtMzIwMDA0Y2E5OTg1&export=download"')
os.system('curl -L -o 2007_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMYWZkOWU1YTItYTUzNS00MmM4LTk1MTktYmI3Y2E1Zjc3OTIy&export=download"')
os.system('curl -L -o 2008_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMZDJmYzIzNWQtNjIyNS00NzQzLWJiMTEtYWI5M2U0MTI4Njlk&export=download"')
os.system('curl -L -o 2009_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMMDAyOGRhMjYtMzlkMC00NGQwLTgxMWUtOWNmYWMxY2Q2ODY3&export=download"')
os.system('curl -L -o 2010_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMMWRkMDc0MDgtZDZhMi00ZGRlLTlkYjEtOTNkZjViZDI0ZGY2&export=download"')
os.system('curl -L -o 2011_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMbmZvYzE3cjBzblE&export=download"')
os.system('curl -L -o 2012_nfl_pbp_data.csv "https://docs.google.com/uc?id=0BxEXxf9odCnMMC1sR3dtNEtHLW8&export=download"')
# Out:
# 0

# %%
pd.set_option('display.line_width', 300)
seasons = range(2003,2013)
pbp_data = pd.read_csv('2002_nfl_pbp_data.csv')
teams = pd.DataFrame(list(set(pbp_data.off))[1:])
teams = teams.rename(columns = {0:'Team_Abr'})
print teams
for i in seasons:
    pbp_data = pbp_data.append(pd.read_csv('%d_nfl_pbp_data.csv' % i))
# Out:
#    Team_Abr
# 0       MIN
# 1       MIA
# 2       CAR
# 3       ATL
# 4       DET
# 5       CIN
# 6       NYJ
# 7       DEN
# 8       BAL
# 9       NYG
# 10      OAK
# 11      TEN
# 12       NO
# 13      DAL
# 14       NE
# 15      SEA
# 16      CHI
# 17      BUF
# 18      PIT
# 19      STL
# 20      CLE
# 21      HOU
# 22       GB
# 23      WAS
# 24      JAC
# 25       KC
# 26      PHI
# 27       TB
# 28      IND
# 29      ARI
# 30       SF
# 31       SD

# %%
pbp_data.head()
# Out:
#             gameid  qtr  min sec  off  def  down  togo  ydline                                        description  offscore  defscore  season
# 0  20020905_SF@NYG    1  NaN   0   SF  NYG   NaN   NaN     NaN  J.Cortez kicks 75 yards from SF 30 to NYG -5. ...         0         0    2002
# 1  20020905_SF@NYG    1   60   0  NYG   SF     1    10      80  (15:00) T.Barber left end to NYG 24 for 4 yard...         0         0    2002
# 2  20020905_SF@NYG    1   59  25  NYG   SF     2     6      76  (14:25) K.Collins pass incomplete to J.Shockey...         0         0    2002
# 3  20020905_SF@NYG    1   59  20  NYG   SF     3     6      76  (14:20) PENALTY on NYG-J.Shockey  False Start ...         0         0    2002
# 4  20020905_SF@NYG    1   59  20  NYG   SF     3    11      81  (14:20) (Shotgun) K.Collins pass intended for ...         0         0    2002

# %%
pbp_data.tail()
# Out:
#                 gameid  qtr  min sec  off def  down  togo  ydline                                        description  offscore  defscore  season
# 44848  20130203_BAL@SF    4    1  42  BAL  SF     2     8      93  (1:42) B.Pierce left end to BLT 7 for no gain ...        34        29    2012
# 44849  20130203_BAL@SF    4    0  56  BAL  SF     3     8      93  (:56) V.Leach right guard to BLT 8 for 1 yard ...        34        29    2012
# 44850  20130203_BAL@SF    4    0  12  BAL  SF     4     7      92  (:12) (Punt formation) S.Koch right end ran ob...        34        29    2012
# 44851  20130203_BAL@SF    4    0  12  BAL  SF   NaN   NaN      92  S.Koch kicks 61 yards from BLT 20 to SF 19. T....        34        31    2012
# 44852  20130203_BAL@SF    4    0  12  BAL  SF   NaN   NaN      92                             ����������������������        34        31    2012

# %%
rank_data1 = (pbp_data.shift(1)).shift(-1)
rank_data2 = pbp_data.shift(1)
rank_data2.rename(columns=lambda x: x + '2', inplace=True)

# %%
rank_data1.head()
# Out:
#             gameid  qtr  min sec  off  def  down  togo  ydline                                        description  offscore  defscore  season
# 0  20020905_SF@NYG    1  NaN   0   SF  NYG   NaN   NaN     NaN  J.Cortez kicks 75 yards from SF 30 to NYG -5. ...         0         0    2002
# 1  20020905_SF@NYG    1   60   0  NYG   SF     1    10      80  (15:00) T.Barber left end to NYG 24 for 4 yard...         0         0    2002
# 2  20020905_SF@NYG    1   59  25  NYG   SF     2     6      76  (14:25) K.Collins pass incomplete to J.Shockey...         0         0    2002
# 3  20020905_SF@NYG    1   59  20  NYG   SF     3     6      76  (14:20) PENALTY on NYG-J.Shockey  False Start ...         0         0    2002
# 4  20020905_SF@NYG    1   59  20  NYG   SF     3    11      81  (14:20) (Shotgun) K.Collins pass intended for ...         0         0    2002

# %%
rank_data2.head()
# Out:
#            gameid2  qtr2  min2 sec2 off2 def2  down2  togo2  ydline2                                       description2  offscore2  defscore2  season2
# 0              NaN   NaN   NaN  NaN  NaN  NaN    NaN    NaN      NaN                                                NaN        NaN        NaN      NaN
# 1  20020905_SF@NYG     1   NaN    0   SF  NYG    NaN    NaN      NaN  J.Cortez kicks 75 yards from SF 30 to NYG -5. ...          0          0     2002
# 2  20020905_SF@NYG     1    60    0  NYG   SF      1     10       80  (15:00) T.Barber left end to NYG 24 for 4 yard...          0          0     2002
# 3  20020905_SF@NYG     1    59   25  NYG   SF      2      6       76  (14:25) K.Collins pass incomplete to J.Shockey...          0          0     2002
# 4  20020905_SF@NYG     1    59   20  NYG   SF      3      6       76  (14:20) PENALTY on NYG-J.Shockey  False Start ...          0          0     2002

# %%
rank_data = rank_data1.join(rank_data2)

# %%
rank_data['offTF'] = rank_data['off'] == rank_data['off2'] 
rank_data['gameIDTF'] = rank_data['gameid']==rank_data['gameid2']
first_play = rank_data[rank_data.all(['offTF']==False and ['gameIDTF'] == True) 
#FirstPlay = rank_data[rank_data['offTF'] == False] and rank_data[rank_data['gameIDTF'] == True]
#firstPlayTwo = firstPlay[rank_data['gameIDTF'] == True]
# Out:
#   File "<ipython-input-46-082722d6d154>", line 5
#     #firstPlayTwo = firstPlay[rank_data['gameIDTF'] == True]
#                                                             ^
# SyntaxError: invalid syntax

# %%
FirstPlay.ix[:,1:15].head()
# Out:
#    qtr  min sec  off  def  down  togo  ydline                                        description  offscore  defscore  season           gameid2  qtr2
# 1    1   60   0  NYG   SF     1    10      80  (15:00) T.Barber left end to NYG 24 for 4 yard...         0         0    2002   20020905_SF@NYG     1
# 1    1   59  54  WAS  NYJ     1    10      71  (14:54) T.Canidate left end to WAS 32 for 3 ya...         0         0    2003  20030904_NYJ@WAS     1
# 1    1   59  51   NE  IND     1    10      63  (14:51) T.Brady pass to D.Givens to IND 44 for...         0         0    2004   20040909_IND@NE     1
# 1    1   59  55  OAK   NE     1    10      72  (14:55) L.Jordan left end to OAK 35 for 7 yard...         0         0    2005   20050908_OAK@NE     1
# 1    1   59  54  MIA  PIT     1    10      68  (14:54) R.Brown up the middle to MIA 35 for 3 ...         0         0    2006  20060907_MIA@PIT     1

# %%
df = df.rename(columns = {'min':'minute'})
df.sec = df.sec.convert_objects(convert_numeric=True)
df.minute = df.minute.convert_objects(convert_numeric=True)
df['time_left'] = df.minute + df.sec/60
df = df.drop(['sec', 'minute'], axis = 1)

# %%
df1 = pd.DataFrame(df.ix[:,['gameid', 'off']])
df1.columns = ['gameid2', 'off2']

# %%
x = [0]*len(df.loc[0])
x = pd.DataFrame(pd.DataFrame(x).T)
x.columns = df.columns

# %%
y = [0,0]
y = pd.DataFrame(pd.DataFrame(y).T)
y.columns = df1.columns

# %%
df = df.append(x, ignore_index = True)
df1 = y.append(df1, ignore_index = True)
df = df.join(df1)

# %%
df.head()
# Out:
#             gameid  qtr  off off rank  def def rank  down  togo  ydline                                        description  offscore  defscore  season  time_left          gameid2 off2
# 0  20020905_SF@NYG    1   SF       13  NYG        3   NaN   NaN     NaN  J.Cortez kicks 75 yards from SF 30 to NYG -5. ...         0         0    2002        NaN                0    0
# 1  20020905_SF@NYG    1  NYG       22   SF       18     1    10      80  (15:00) T.Barber left end to NYG 24 for 4 yard...         0         0    2002  60.000000  20020905_SF@NYG   SF
# 2  20020905_SF@NYG    1  NYG       22   SF       18     2     6      76  (14:25) K.Collins pass incomplete to J.Shockey...         0         0    2002  59.416667  20020905_SF@NYG  NYG
# 3  20020905_SF@NYG    1  NYG       22   SF       18     3     6      76  (14:20) PENALTY on NYG-J.Shockey  False Start ...         0         0    2002  59.333333  20020905_SF@NYG  NYG
# 4  20020905_SF@NYG    1  NYG       22   SF       18     3    11      81  (14:20) (Shotgun) K.Collins pass intended for ...         0         0    2002  59.333333  20020905_SF@NYG  NYG

# %%
df.to_csv('destination.csv', sep = ',')
