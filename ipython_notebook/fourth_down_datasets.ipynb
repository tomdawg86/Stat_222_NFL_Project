# %%
import pandas as pd
import numpy as np
import math
import csv
import statsmodels.api as sm

# %%
pd.set_option('display.line_width', 300)
df = pd.read_csv('FourthDownPlays.csv')
df.head(2)
# Out:
#    Unnamed: 0           gameid  qtr  min   sec  off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank
# 0          10  20020905_SF@NYG    1   56  59.0   SF  NYG     4     7       7  (11:59) J.Cortez 25 yard field goal is BLOCKED...         0         0    2002        7       29
# 1          25  20020905_SF@NYG    1   51   4.0  NYG   SF     4     8      11  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...         0         0    2002       19        6

# %%
cond = df['description'].str.contains('field goal' or 'Field Goal' or 'field Goal' or 'Field goal' or 'FIELD GOAL')
field_goal_data = df[cond == True]
field_goal_data.head(2)
# Out:
#    Unnamed: 0           gameid  qtr  min   sec  off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank
# 0          10  20020905_SF@NYG    1   56  59.0   SF  NYG     4     7       7  (11:59) J.Cortez 25 yard field goal is BLOCKED...         0         0    2002        7       29
# 1          25  20020905_SF@NYG    1   51   4.0  NYG   SF     4     8      11  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...         0         0    2002       19        6

# %%
field_goal_data['converted'] = field_goal_data['description'].str.contains('GOOD')
field_goal_data['distance'] = field_goal_data['ydline'] + 18
field_goal = field_goal_data[['ydline', 'distance', 'description', 'converted']]  
field_goal.head()
# Out:
#     ydline  distance                                        description converted
# 0        7        25  (11:59) J.Cortez 25 yard field goal is BLOCKED...     False
# 1       11        29  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...      True
# 2        5        23  (1:03) J.Cortez 23 yard field goal is GOOD  Ce...      True
# 6       30        48  (1:09) J.Cortez 48 yard field goal is No Good ...     False
# 11      15        33  (8:13) J.Cortez 33 yard field goal is GOOD  Ce...      True

# %%
field_goal['intercept'] = [1]*len(field_goal)
field_goal_logit = sm.Logit(field_goal[['converted']], field_goal[['intercept','ydline']])
field_goal_result = field_goal_logit.fit()
field_goal_result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.410646
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              converted   No. Observations:                10029
# Model:                          Logit   Df Residuals:                    10027
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 28 Feb 2014   Pseudo R-squ.:                  0.1209
# Time:                        16:57:33   Log-Likelihood:                -4118.4
# converged:                       True   LL-Null:                       -4684.5
#                                         LLR p-value:                3.084e-248
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# intercept      3.5990      0.081     44.419      0.000         3.440     3.758
# ydline        -0.0983      0.003    -30.337      0.000        -0.105    -0.092
# ==============================================================================
# """

# %%
field_goal_result.predict([1, 30], True)
# Out:
# 0.6566954007904009

# %%
cond2 = df['description'].str.contains('punt' or 'PUNT' or 'Punt')
punt_data = df[cond2 == True]
punt_data.head(2)
# Out:
#    Unnamed: 0           gameid  qtr  min   sec  off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank
# 4          58  20020905_SF@NYG    2   35  32.0   SF  NYG     4     2      68  (5:32) J.Baker punts 47 yards to NYG 21  Cente...         3         3    2002        7       29
# 5          62  20020905_SF@NYG    2   34  27.0  NYG   SF     4     8      82  (4:27) M.Allen punts 44 yards to SF 38  Center...         3         3    2002       19        6

# %%
punt_data['ydlineotherteam'] = 100 - (punt_data['ydline']-39)
punt_data_final = punt_data[['description', 'ydline', 'ydlineotherteam']]
punt_data_final.head()
# Out:
#                                          description  ydline  ydlineotherteam
# 4  (5:32) J.Baker punts 47 yards to NYG 21  Cente...      68               71
# 5  (4:27) M.Allen punts 44 yards to SF 38  Center...      82               57
# 7  (13:21) J.Baker punts 45 yards to NYG 18  Cent...      63               76
# 8  (10:09) M.Allen punts 24 yards to SF 42  Cente...      66               73
# 9  (8:46) J.Baker punts 41 yards to NYG 14  Cente...      55               84

# %%
go = df[cond == False]
cond2 = go['description'].str.contains('punt' or 'PUNT' or 'Punt')
go_for_it = go[cond2 == False]
go_for_it.head(2)
# Out:
#     Unnamed: 0            gameid  qtr  min   sec  off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank
# 3           53   20020905_SF@NYG    2   38   6.0  NYG   SF     4     1      21  (8:06) T.Barber left tackle to SF 24 for -3 ya...         3         3    2002       19        6
# 26         365  20020908_ARI@WAS    2   42  37.0  WAS  ARI     4     1      41  (12:37) S.Davis right end to ARZ 39 for 2 yard...         3        10    2002       23       14

# %%
pbp = pd.read_csv('all_season_pbp_data.csv')
pbp.head(1)
# Out:
#    Unnamed: 0           gameid  qtr  min sec off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank
# 0           0  20020905_SF@NYG    1  NaN   0  SF  NYG   NaN   NaN     NaN  J.Cortez kicks 75 yards from SF 30 to NYG -5. ...         0         0    2002        7       29

# %%
play_after_going_for_it = pbp.ix[go_for_it['Unnamed: 0'] + 1, :]
play_after_gfi_important_vars = play_after_going_for_it[['ydline', 'offrank']]
play_after_gfi_important_vars.head(2)
# Out:
#      ydline  offrank
# 54       76        7
# 366      39       23

# %%
play_after_gfi_important_vars.columns = ['ydline2', 'offrank2']
play_after_gfi_important_vars.index = go_for_it.index
go_for_it_2 = go_for_it.join(play_after_gfi_important_vars)
go_for_it_2['converted'] = go_for_it_2['offrank'] == go_for_it_2['offrank2']
go_for_it_2.head(2)
# Out:
#     Unnamed: 0            gameid  qtr  min   sec  off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank  ydline2  offrank2 converted
# 3           53   20020905_SF@NYG    2   38   6.0  NYG   SF     4     1      21  (8:06) T.Barber left tackle to SF 24 for -3 ya...         3         3    2002       19        6       76         7     False
# 26         365  20020908_ARI@WAS    2   42  37.0  WAS  ARI     4     1      41  (12:37) S.Davis right end to ARZ 39 for 2 yard...         3        10    2002       23       14       39        23      True

# %%
go_for_it_final = go_for_it_2[['offrank', 'defrank', 'togo', 'converted']]
go_for_it_final.head()
# Out:
#     offrank  defrank  togo converted
# 3        19        6     1     False
# 26       23       14     1      True
# 30       23       14     2     False
# 47        6        2     1      True
# 63       24       31    10     False

# %%
go_for_it_final['intercept'] = [1]*len(go_for_it_final)
go_for_it_logit = sm.Logit(go_for_it_final[['converted']], go_for_it_final[['intercept','togo', 'offrank', 'defrank']])
go_for_it_result = go_for_it_logit.fit()
go_for_it_result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.655029
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              converted   No. Observations:                 5751
# Model:                          Logit   Df Residuals:                     5747
# Method:                           MLE   Df Model:                            3
# Date:                Fri, 28 Feb 2014   Pseudo R-squ.:                 0.05422
# Time:                        17:22:49   Log-Likelihood:                -3767.1
# converged:                       True   LL-Null:                       -3983.1
#                                         LLR p-value:                 2.640e-93
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# intercept      0.8790      0.078     11.301      0.000         0.727     1.031
# togo          -0.1218      0.007    -18.401      0.000        -0.135    -0.109
# offrank       -0.0098      0.003     -3.278      0.001        -0.016    -0.004
# defrank       -0.0054      0.003     -1.816      0.069        -0.011     0.000
# ==============================================================================
# """

# %%
go_for_it_result.predict([1, 1, 16, 32], True)
# Out:
# 0.60545235553589261

# %% [raw]
# We should bucket defensive and offensive buckets because defensive rank should make an impact on conversion rate. Maybe, really weak defenses are not test on fourth down very often.

# %%
go_for_it_final['intercept'] = [1]*len(go_for_it_final)
go_for_it_logit = sm.Logit(go_for_it_final[['converted']], go_for_it_final[['intercept','togo', 'offrank']])
go_for_it_result = go_for_it_logit.fit()
go_for_it_result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.655316
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              converted   No. Observations:                 5751
# Model:                          Logit   Df Residuals:                     5748
# Method:                           MLE   Df Model:                            2
# Date:                Fri, 28 Feb 2014   Pseudo R-squ.:                 0.05381
# Time:                        17:40:44   Log-Likelihood:                -3768.7
# converged:                       True   LL-Null:                       -3983.1
#                                         LLR p-value:                 8.266e-94
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# intercept      0.7970      0.063     12.624      0.000         0.673     0.921
# togo          -0.1218      0.007    -18.397      0.000        -0.135    -0.109
# offrank       -0.0104      0.003     -3.516      0.000        -0.016    -0.005
# ==============================================================================
# """

# %%
go_for_it_result.predict([1, 10, 32], True)
# Out:
# 0.31957201403319696
