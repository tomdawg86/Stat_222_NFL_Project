# %%
import pandas as pd
import numpy as np
import math
import csv
import scipy as sp
#import statsmodels as sm
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-557f661c052d> in <module>()
#       5 import scipy as sp
#       6 import statsmodels as sm
# ----> 7 import statsmodels.api as sm
#
# /Users/apple/anaconda/lib/python2.7/site-packages/statsmodels/api.py in <module>()
# ----> 1 import iolib, datasets, tools
#       2 from tools.tools import add_constant, categorical
#       3 import regression
#       4 from .regression.linear_model import OLS, GLS, WLS, GLSAR
#       5 from .regression.quantile_regression import QuantReg
#
# /Users/apple/anaconda/lib/python2.7/site-packages/statsmodels/iolib/__init__.py in <module>()
# ----> 1 from foreign import StataReader, genfromdta, savetxt
#       2 from table import SimpleTable, csv2st
#       3 from smpickle import save_pickle, load_pickle
#       4
#       5 from statsmodels import NoseWrapper as Tester
#
# /Users/apple/anaconda/lib/python2.7/site-packages/statsmodels/iolib/foreign.py in <module>()
#      18 from numpy.lib._iotools import _is_string_like, easy_dtype
#      19 from statsmodels.compatnp.py3k import asbytes, asstr
# ---> 20 import statsmodels.tools.data as data_util
#      21 from pandas import isnull
#      22
#
# /Users/apple/anaconda/lib/python2.7/site-packages/statsmodels/tools/__init__.py in <module>()
# ----> 1 from tools import add_constant, categorical
#       2
#       3 from statsmodels import NoseWrapper as Tester
#       4 test = Tester().test
#
# /Users/apple/anaconda/lib/python2.7/site-packages/statsmodels/tools/tools.py in <module>()
#       6 import numpy.lib.recfunctions as nprf
#       7 import numpy.linalg as L
# ----> 8 from scipy.interpolate import interp1d
#       9 from scipy.linalg import svdvals
#      10 from statsmodels.distributions import (ECDF, monotone_fn_inverter,
#
# /Users/apple/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/interpolate/__init__.py in <module>()
#     154 from .fitpack2 import *
#     155
# --> 156 from .rbf import Rbf
#     157
#     158 from .polyint import *
#
# /Users/apple/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/interpolate/rbf.py in <module>()
#      49 from numpy import (sqrt, log, asarray, newaxis, all, dot, exp, eye,
#      50                    float_)
# ---> 51 from scipy import linalg
#      52 from scipy.lib.six import callable, get_method_function, \
#      53      get_function_code
#
# /Users/apple/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/linalg/__init__.py in <module>()
#     145 from .linalg_version import linalg_version as __version__
#     146
# --> 147 from .misc import *
#     148 from .basic import *
#     149 from .decomp import *
#
# /Users/apple/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/linalg/misc.py in <module>()
#       3 import numpy as np
#       4 from numpy.linalg import LinAlgError
# ----> 5 from . import blas
#       6
#       7 __all__ = ['LinAlgError', 'norm']
#
# /Users/apple/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/linalg/blas.py in <module>()
#     111 import numpy as _np
#     112
# --> 113 from scipy.linalg import _fblas
#     114 try:
#     115     from scipy.linalg import _cblas
#
# ImportError: dlopen(/Users/apple/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/linalg/_fblas.so, 2): Library not loaded: @rpath/libmkl_intel_lp64.dylib
#   Referenced from: /Users/apple/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/linalg/_fblas.so
#   Reason: image not found

# %%
pd.set_option('display.line_width', 300)
df = pd.read_csv('FourthDownPlays.csv')
df.head(2)
# Out:
#    Unnamed: 0           gameid  qtr  min   sec  off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank offrankbucket defrankbucket togobucket
# 0          10  20020905_SF@NYG    1   56  59.0   SF  NYG     4     7       7  (11:59) J.Cortez 25 yard field goal is BLOCKED...         0         0    2002        7        6        (6-10)        (6-10)      (7-8)
# 1          25  20020905_SF@NYG    1   51   4.0  NYG   SF     4     8      11  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...         0         0    2002       19       29       (16-20)       (26-32)      (7-8)

# %%
cond = df['description'].str.contains('field goal' or 'Field Goal' or 'field Goal' or 'Field goal' or 'FIELD GOAL')
field_goal_data = df[cond == True]
field_goal_data.head(2)
# Out:
#    Unnamed: 0           gameid  qtr  min   sec  off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank offrankbucket defrankbucket togobucket
# 0          10  20020905_SF@NYG    1   56  59.0   SF  NYG     4     7       7  (11:59) J.Cortez 25 yard field goal is BLOCKED...         0         0    2002        7        6        (6-10)        (6-10)      (7-8)
# 1          25  20020905_SF@NYG    1   51   4.0  NYG   SF     4     8      11  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...         0         0    2002       19       29       (16-20)       (26-32)      (7-8)

# %%
field_goal_data['converted'] = field_goal_data['description'].str.contains('GOOD')
field_goal_data['distance'] = field_goal_data['ydline'] + 18
field_goal = field_goal_data[['ydline', 'distance', 'description', 'converted']]  
field_goal.head()
# Out:
#     ydline  distance                                        description converted
# 0        7        25  (11:59) J.Cortez 25 yard field goal is BLOCKED...     False
# 1       11        29  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...      True
# 2        5        23  (1:03) J.Cortez 23 yard field goal is GOOD  Ce...      True
# 6       30        48  (1:09) J.Cortez 48 yard field goal is No Good ...     False
# 11      15        33  (8:13) J.Cortez 33 yard field goal is GOOD  Ce...      True

# %%
field_goal['intercept'] = [1]*len(field_goal)
field_goal_logit = sm.Logit(field_goal[['converted']], field_goal[['intercept','ydline']])
field_goal_result = field_goal_logit.fit()
field_goal_result.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-86043c59a449> in <module>()
#       1 field_goal['intercept'] = [1]*len(field_goal)
# ----> 2 field_goal_logit = sm.Logit(field_goal[['converted']], field_goal[['intercept','ydline']])
#       3 field_goal_result = field_goal_logit.fit()
#       4 field_goal_result.summary()
#
# AttributeError: 'module' object has no attribute 'Logit'

# %%
field_goal_result.predict([1, 30], True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5b4ef5049973> in <module>()
# ----> 1 field_goal_result.predict([1, 30], True)
#
# NameError: name 'field_goal_result' is not defined

# %%
cond2 = df['description'].str.contains('punt' or 'PUNT' or 'Punt')
punt_data = df[cond2 == True]
punt_data.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 7317 to 9772
# Data columns (total 39 columns):
# Unnamed: 0            2  non-null values
# Unnamed: 0.1          2  non-null values
# gameid                2  non-null values
# qtr                   2  non-null values
# min                   2  non-null values
# sec                   2  non-null values
# off                   1  non-null values
# def                   2  non-null values
# down                  2  non-null values
# togo                  2  non-null values
# ydline                2  non-null values
# description           2  non-null values
# offscore              2  non-null values
# defscore              2  non-null values
# season                2  non-null values
# offrank               1  non-null values
# defrank               2  non-null values
# offrankbucket         1  non-null values
# defrankbucket         2  non-null values
# togobucket            2  non-null values
# last_Unnamed: 0       2  non-null values
# last_gameid           2  non-null values
# last_qtr              2  non-null values
# last_min              2  non-null values
# last_sec              2  non-null values
# last_off              1  non-null values
# last_def              2  non-null values
# last_down             2  non-null values
# last_togo             2  non-null values
# last_ydline           2  non-null values
# last_description      2  non-null values
# last_offscore         2  non-null values
# last_defscore         2  non-null values
# last_season           2  non-null values
# last_offrank          1  non-null values
# last_defrank          2  non-null values
# last_offrankbucket    1  non-null values
# last_defrankbucket    2  non-null values
# last_togobucket       2  non-null values
# dtypes: float64(22), int64(1), object(16)

# %%
punt_data['ydlineotherteam'] = 100 - (punt_data['ydline']-39)
punt_data_final = punt_data[['description', 'ydline', 'ydlineotherteam']]
punt_data_final.head()
# Out:
#                                              description  ydline  ydlineotherteam
# 7317   (11:03) E. Johnson punts 39 yards to SF 28 Cen...      67               72
# 9772   (11:26) J. Baker punts 42 yards to CIN 40 Cent...      18              121
# 16529  (11:09) M.Scifres punts 29 yards to KC 16 Cent...      45               94
# 20601  (:03) (Punt formation) D.Jones Aborted. J.Denn...      55               84
# 22758  (12:08)  Change of direction following the pun...      95               44

# %%
go = df[cond == False]
cond2 = go['description'].str.contains('punt' or 'PUNT' or 'Punt')
go_for_it = go[cond2 == False]
go_for_it.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 1
# Data columns (total 39 columns):
# Unnamed: 0            2  non-null values
# Unnamed: 0.1          2  non-null values
# gameid                2  non-null values
# qtr                   2  non-null values
# min                   2  non-null values
# sec                   2  non-null values
# off                   2  non-null values
# def                   2  non-null values
# down                  2  non-null values
# togo                  2  non-null values
# ydline                2  non-null values
# description           2  non-null values
# offscore              2  non-null values
# defscore              2  non-null values
# season                2  non-null values
# offrank               2  non-null values
# defrank               2  non-null values
# offrankbucket         2  non-null values
# defrankbucket         2  non-null values
# togobucket            2  non-null values
# last_Unnamed: 0       2  non-null values
# last_gameid           2  non-null values
# last_qtr              2  non-null values
# last_min              2  non-null values
# last_sec              2  non-null values
# last_off              2  non-null values
# last_def              2  non-null values
# last_down             2  non-null values
# last_togo             2  non-null values
# last_ydline           2  non-null values
# last_description      2  non-null values
# last_offscore         2  non-null values
# last_defscore         2  non-null values
# last_season           2  non-null values
# last_offrank          2  non-null values
# last_defrank          2  non-null values
# last_offrankbucket    2  non-null values
# last_defrankbucket    2  non-null values
# last_togobucket       2  non-null values
# dtypes: float64(22), int64(1), object(16)

# %%
pbp = pd.read_csv('all_season_pbp_data.csv')
pbp.head(1)
# Out:
#    Unnamed: 0           gameid  qtr  min sec off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank offrankbucket defrankbucket togobucket
# 0           0  20020905_SF@NYG    1  NaN   0  SF  NYG   NaN   NaN     NaN  J.Cortez kicks 75 yards from SF 30 to NYG -5. ...         0         0    2002        7        6        (6-10)        (6-10)        NaN

# %%
play_after_going_for_it = pbp.ix[go_for_it['Unnamed: 0'] + 1, :]
play_after_gfi_important_vars = play_after_going_for_it[['ydline', 'offrank']]
play_after_gfi_important_vars.head(2)
# Out:
#    ydline  offrank
# 2      76       19
# 6       7        7

# %%
play_after_gfi_important_vars.columns = ['ydline2', 'offrank2']
play_after_gfi_important_vars.index = go_for_it.index
go_for_it_2 = go_for_it.join(play_after_gfi_important_vars)
go_for_it_2['converted'] = go_for_it_2['offrank'] == go_for_it_2['offrank2']
go_for_it_2.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 1
# Data columns (total 42 columns):
# Unnamed: 0            2  non-null values
# Unnamed: 0.1          2  non-null values
# gameid                2  non-null values
# qtr                   2  non-null values
# min                   2  non-null values
# sec                   2  non-null values
# off                   2  non-null values
# def                   2  non-null values
# down                  2  non-null values
# togo                  2  non-null values
# ydline                2  non-null values
# description           2  non-null values
# offscore              2  non-null values
# defscore              2  non-null values
# season                2  non-null values
# offrank               2  non-null values
# defrank               2  non-null values
# offrankbucket         2  non-null values
# defrankbucket         2  non-null values
# togobucket            2  non-null values
# last_Unnamed: 0       2  non-null values
# last_gameid           2  non-null values
# last_qtr              2  non-null values
# last_min              2  non-null values
# last_sec              2  non-null values
# last_off              2  non-null values
# last_def              2  non-null values
# last_down             2  non-null values
# last_togo             2  non-null values
# last_ydline           2  non-null values
# last_description      2  non-null values
# last_offscore         2  non-null values
# last_defscore         2  non-null values
# last_season           2  non-null values
# last_offrank          2  non-null values
# last_defrank          2  non-null values
# last_offrankbucket    2  non-null values
# last_defrankbucket    2  non-null values
# last_togobucket       2  non-null values
# ydline2               2  non-null values
# offrank2              2  non-null values
# converted             2  non-null values
# dtypes: bool(1), float64(24), int64(1), object(16)

# %%
go_for_it_final = go_for_it_2[['offrank', 'defrank', 'togo', 'converted']]
go_for_it_final.head()
# Out:
#    offrank  defrank  togo converted
# 0       19       29    10      True
# 1        7        6    10      True
# 2       19       29    10      True
# 3        7        6    10      True
# 4       19       29    10      True

# %%
go_for_it_final['intercept'] = [1]*len(go_for_it_final)
go_for_it_logit = sm.Logit(go_for_it_final[['converted']], go_for_it_final[['intercept','togo', 'offrank', 'defrank']])
go_for_it_result = go_for_it_logit.fit()
go_for_it_result.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-08b5964b1c2e> in <module>()
#       1 go_for_it_final['intercept'] = [1]*len(go_for_it_final)
# ----> 2 go_for_it_logit = sm.Logit(go_for_it_final[['converted']], go_for_it_final[['intercept','togo', 'offrank', 'defrank']])
#       3 go_for_it_result = go_for_it_logit.fit()
#       4 go_for_it_result.summary()
#
# AttributeError: 'module' object has no attribute 'Logit'

# %%
go_for_it_result.predict([1, 1, 16, 32], True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-1750d8e0d1cd> in <module>()
# ----> 1 go_for_it_result.predict([1, 1, 16, 32], True)
#
# NameError: name 'go_for_it_result' is not defined

# %% [raw]
# We should bucket defensive and offensive buckets because defensive rank should make an impact on conversion rate. Maybe, really weak defenses are not test on fourth down very often.

# %%
go_for_it_final['intercept'] = [1]*len(go_for_it_final)
go_for_it_logit = sm.Logit(go_for_it_final[['converted']], go_for_it_final[['intercept','togo', 'offrank']])
go_for_it_result = go_for_it_logit.fit()
go_for_it_result.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-0b286238714b> in <module>()
#       1 go_for_it_final['intercept'] = [1]*len(go_for_it_final)
# ----> 2 go_for_it_logit = sm.Logit(go_for_it_final[['converted']], go_for_it_final[['intercept','togo', 'offrank']])
#       3 go_for_it_result = go_for_it_logit.fit()
#       4 go_for_it_result.summary()
#
# AttributeError: 'module' object has no attribute 'Logit'

# %%
go_for_it_result.predict([1, 10, 32], True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-6c743fcce3c3> in <module>()
# ----> 1 go_for_it_result.predict([1, 10, 32], True)
#
# NameError: name 'go_for_it_result' is not defined
