# %%
import pandas as pd
import numpy as np
import math
import csv

# %%
pd.set_option('display.line_width', 300)
df = pd.read_csv('FourthDownPlays.csv')
df.head()
# Out:
#    Unnamed: 0           gameid  qtr  min   sec  off off rank  def def rank  down  togo  ydline                                        description  offscore  defscore  season
# 0          10  20020905_SF@NYG    1   56  59.0   SF       13  NYG        3     4     7       7  (11:59) J.Cortez 25 yard field goal is BLOCKED...         0         0    2002
# 1          25  20020905_SF@NYG    1   51   4.0  NYG       22   SF       18     4     8      11  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...         0         0    2002
# 2          35  20020905_SF@NYG    1   46   3.0   SF       13  NYG        3     4     5       5  (1:03) J.Cortez 23 yard field goal is GOOD  Ce...         0         3    2002
# 3          53  20020905_SF@NYG    2   38   6.0  NYG       22   SF       18     4     1      21  (8:06) T.Barber left tackle to SF 24 for -3 ya...         3         3    2002
# 4          58  20020905_SF@NYG    2   35  32.0   SF       13  NYG        3     4     2      68  (5:32) J.Baker punts 47 yards to NYG 21  Cente...         3         3    2002

# %%
cond = df['description'].str.contains('field goal' or 'Field Goal' or 'field Goal' or 'Field goal' or 'FIELD GOAL')
field_goal_data = df[cond == True]
field_goal_data.head()
# Out:
#     Unnamed: 0           gameid  qtr  min   sec  off off rank  def def rank  down  togo  ydline                                        description  offscore  defscore  season
# 0           10  20020905_SF@NYG    1   56  59.0   SF       13  NYG        3     4     7       7  (11:59) J.Cortez 25 yard field goal is BLOCKED...         0         0    2002
# 1           25  20020905_SF@NYG    1   51   4.0  NYG       22   SF       18     4     8      11  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...         0         0    2002
# 2           35  20020905_SF@NYG    1   46   3.0   SF       13  NYG        3     4     5       5  (1:03) J.Cortez 23 yard field goal is GOOD  Ce...         0         3    2002
# 6           71  20020905_SF@NYG    2   31   9.0   SF       13  NYG        3     4     2      30  (1:09) J.Cortez 48 yard field goal is No Good ...         3         3    2002
# 11         130  20020905_SF@NYG    4    8  13.0   SF       13  NYG        3     4     9      15  (8:13) J.Cortez 33 yard field goal is GOOD  Ce...        10         6    2002

# %%
pbp = pd.read_csv('all_season_pbp_data.csv')
pbp.head()
# Out:
#    Unnamed: 0           gameid  qtr  min sec  off  def  down  togo  ydline                                        description  offscore  defscore  season  offrank  defrank
# 0           0  20020905_SF@NYG    1  NaN   0   SF  NYG   NaN   NaN     NaN  J.Cortez kicks 75 yards from SF 30 to NYG -5. ...         0         0    2002        7       29
# 1           1  20020905_SF@NYG    1   60   0  NYG   SF     1    10      80  (15:00) T.Barber left end to NYG 24 for 4 yard...         0         0    2002       19        6
# 2           2  20020905_SF@NYG    1   59  25  NYG   SF     2     6      76  (14:25) K.Collins pass incomplete to J.Shockey...         0         0    2002       19        6
# 3           3  20020905_SF@NYG    1   59  20  NYG   SF     3     6      76  (14:20) PENALTY on NYG-J.Shockey  False Start ...         0         0    2002       19        6
# 4           4  20020905_SF@NYG    1   59  20  NYG   SF     3    11      81  (14:20) (Shotgun) K.Collins pass intended for ...         0         0    2002       19        6

# %%
play_after_field_goal = pbp.ix[field_goal_data['Unnamed: 0'] + 1, :]
#field_goal_data['offscore2'] = play_after_field_goal['offscore']
#field_goal_data.head()
# Out:
#     Unnamed: 0           gameid  qtr  min   sec  off off rank  def def rank  down  togo  ydline                                        description  offscore  defscore  season  offcore2
# 0           10  20020905_SF@NYG    1   56  59.0   SF       13  NYG        3     4     7       7  (11:59) J.Cortez 25 yard field goal is BLOCKED...         0         0    2002       NaN
# 1           25  20020905_SF@NYG    1   51   4.0  NYG       22   SF       18     4     8      11  (6:04) M.Bryant 29 yard field goal is GOOD  Ce...         0         0    2002       NaN
# 2           35  20020905_SF@NYG    1   46   3.0   SF       13  NYG        3     4     5       5  (1:03) J.Cortez 23 yard field goal is GOOD  Ce...         0         3    2002       NaN
# 6           71  20020905_SF@NYG    2   31   9.0   SF       13  NYG        3     4     2      30  (1:09) J.Cortez 48 yard field goal is No Good ...         3         3    2002       NaN
# 11         130  20020905_SF@NYG    4    8  13.0   SF       13  NYG        3     4     9      15  (8:13) J.Cortez 33 yard field goal is GOOD  Ce...        10         6    2002         0

# %%
cond2 = df['description'].str.contains('punt' or 'PUNT' or 'Punt')
punt_data = df[cond2 == True]
punt_data.head()
# Out:
#    Unnamed: 0           gameid  qtr  min   sec  off off rank  def def rank  down  togo  ydline                                        description  offscore  defscore  season
# 4          58  20020905_SF@NYG    2   35  32.0   SF       13  NYG        3     4     2      68  (5:32) J.Baker punts 47 yards to NYG 21  Cente...         3         3    2002
# 5          62  20020905_SF@NYG    2   34  27.0  NYG       22   SF       18     4     8      82  (4:27) M.Allen punts 44 yards to SF 38  Center...         3         3    2002
# 7          84  20020905_SF@NYG    3   28  21.0   SF       13  NYG        3     4     5      63  (13:21) J.Baker punts 45 yards to NYG 18  Cent...         3         6    2002
# 8          91  20020905_SF@NYG    3   25   9.0  NYG       22   SF       18     4     6      66  (10:09) M.Allen punts 24 yards to SF 42  Cente...         6         3    2002
# 9          95  20020905_SF@NYG    3   23  46.0   SF       13  NYG        3     4     7      55  (8:46) J.Baker punts 41 yards to NYG 14  Cente...         3         6    2002

# %%
go = df[cond == False]
cond3 = df['description'].str.contains('punt' or 'PUNT' or 'Punt')
go_for_it = go[cond3 == False]
go_for_it.head()
# Out:
# 5751
